# %% [markdown]
# # Laboratory Exercise 1: Introduction to Google Earth Engine (GEE)
# In this lab, you will learn how to initialize Google Earth Engine (GEE), select satellite images, visualize data, and analyze basic metadata.

# %% [markdown]
# ## Task 1: Initialize Google Earth Engine
# Authenticate and initialize the Google Earth Engine (GEE) API.

# %%
import ee
import geemap.foliumap as geemap 
import ssl
import webbrowser

ssl._create_default_https_context = ssl._create_stdlib_context
# Authenticate and initialize GEE
# TODO: Use the Earth Engine library to authenticate and initialize your session
#ee.Authenticate()
ee.Initialize(project='ee-juliaszymanska142')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Task 2: Define Area of Interest (AOI)
# Define your area of interest (AOI). You can use either a point or a bounding box.
# Example coordinates are provided below (Krakow, Poland). Adjust them for your location.

# %%
import ee

# Define AOI
# TODO: Replace with your coordinates
point = [19.91, 50.06]
aoi = ee.Geometry.Point(point) 


# or
# aoi = ee.Geometry.Rectangle([west, south, east, north])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Task 3: Retrieve Sentinel-2 Data
# Retrieve Sentinel-2 imagery for your defined AOI within a specific date range. Sort the images based on cloud cover percentage.

# %%
# TODO: Adjust the date range and retrieve the least cloudy Sentinel-2 image
sentinel_collection = (
    ee.ImageCollection('COPERNICUS/S2_HARMONIZED')
    .filterBounds(aoi)  
    .filterDate('2025-01-01', '2025-02-01')  
    .sort('CLOUDY_PIXEL_PERCENTAGE')  
)


best_image = sentinel_collection.first()


image_info = best_image.getInfo()
print("Best image:", image_info['id'])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Best image: COPERNICUS/S2_HARMONIZED/20250118T094229_20250118T094230_T34UDA

# %% [markdown]
# ## Task 4: Extract Image Metadata
# Extract and print metadata from the selected image, such as ID, cloud cover percentage, mean solar azimuth and zenith angles, and processing level.

# %%
# Extract metadata
# TODO: Retrieve and display image metadata
metadata = sentinel_collection.getInfo()
metadata
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'ImageCollection',
#  'bands': [],
#  'version': 1742414438806166,
#  'id': 'COPERNICUS/S2_HARMONIZED',
#  'properties': {'date_range': [1435017600000, 1647993600000],
#   'period': 0,
#   'system:visualization_0_min': '0.0',
#   'type_name': 'ImageCollection',
#   'keywords': ['copernicus', 'esa', 'eu', 'msi', 'radiance', 'sentinel'],
#   'system:visualization_0_bands': 'B4,B3,B2',
#   'thumb': 'https://mw1.google.com/ges/dd/images/sentinel2_thumb.png',
#   'description': '<p>Sentinel-2 is a wide-swath, high-resolution, multi-spectral\nimaging mission supporting Copernicus Land Monitoring studies,\nincluding the monitoring of vegetation, soil and water cover,\nas well as observation of inland waterways and coastal areas.</p><p>The Sentinel-2 data contain 13 UINT16 spectral bands representing\nTOA reflectance scaled by 10000. See the <a href="https://sentinel.esa.int/documents/247904/685211/Sentinel-2_User_Handbook">Sentinel-2 User Handbook</a>\nfor details. In addition, three QA bands are present where one\n(QA60) is a bitmask band with cloud mask information. For more\ndetails, <a href="https://sentinel.esa.int/web/sentinel/technical-guides/sentinel-2-msi/level-1c/cloud-masks">see the full explanation of how cloud masks are computed.</a></p><p>Each Sentinel-2 product (zip archive) may contain multiple\ngranules. Each granule becomes a separate Earth Engine asset.\nEE asset ids for Sentinel-2 assets have the following format:\nCOPERNICUS/S2/20151128T002653_20151128T102149_T56MNN. Here the\nfirst numeric part represents the sensing date and time, the\nsecond numeric part represents the product generation date and\ntime, and the final 6-character string is a unique granule identifier\nindicating its UTM grid reference (see <a href="https://en.wikipedia.org/wiki/Military_Grid_Reference_System">MGRS</a>).</p><p>The Level-2 data produced by ESA can be found in the collection\n<a href="COPERNICUS_S2_SR">COPERNICUS/S2_SR</a>.</p><p>Clouds can be mostly removed by using\n<a href="COPERNICUS_S2_CLOUD_PROBABILITY">COPERNICUS/S2_CLOUD_PROBABILITY</a>.\nSee\n<a href="https://developers.google.com/earth-engine/tutorials/community/sentinel-2-s2cloudless">this tutorial</a>\nexplaining how to apply the cloud mask.</p><p>For more details on Sentinel-2 radiometric resolution, <a href="https://earth.esa.int/web/sentinel/user-guides/sentinel-2-msi/resolutions/radiometric">see this page</a>.</p><p><b>Provider: <a href="https://earth.esa.int/web/sentinel/user-guides/sentinel-2-msi/product-types/level-1c">European Union/ESA/Copernicus</a></b><br><p><b>Revisit Interval</b><br>\n  5 days\n</p><p><b>Bands</b><table class="eecat"><tr><th scope="col">Name</th><th scope="col">Description</th></tr><tr><td>B1</td><td><p>Aerosols</p></td></tr><tr><td>B2</td><td><p>Blue</p></td></tr><tr><td>B3</td><td><p>Green</p></td></tr><tr><td>B4</td><td><p>Red</p></td></tr><tr><td>B5</td><td><p>Red Edge 1</p></td></tr><tr><td>B6</td><td><p>Red Edge 2</p></td></tr><tr><td>B7</td><td><p>Red Edge 3</p></td></tr><tr><td>B8</td><td><p>NIR</p></td></tr><tr><td>B8A</td><td><p>Red Edge 4</p></td></tr><tr><td>B9</td><td><p>Water vapor</p></td></tr><tr><td>B10</td><td><p>Cirrus</p></td></tr><tr><td>B11</td><td><p>SWIR 1</p></td></tr><tr><td>B12</td><td><p>SWIR 2</p></td></tr><tr><td>QA10</td><td><p>Always empty</p></td></tr><tr><td>QA20</td><td><p>Always empty</p></td></tr><tr><td>QA60</td><td><p>Cloud mask</p></td></tr><tr><td colspan=100>\n      Bitmask for QA60\n<ul><li>\n          Bit 10: Opaque clouds\n<ul><li>0: No opaque clouds</li><li>1: Opaque clouds present</li></ul></li><li>\n          Bit 11: Cirrus clouds\n<ul><li>0: No cirrus clouds</li><li>1: Cirrus clouds present</li></ul></li></ul></td></tr></table><p><b>Image Properties</b><table class="eecat"><tr><th scope="col">Name</th><th scope="col">Type</th><th scope="col">Description</th></tr><tr><td>CLOUDY_PIXEL_PERCENTAGE</td><td>DOUBLE</td><td><p>Granule-specific cloudy pixel percentage taken from the original metadata</p></td></tr><tr><td>CLOUD_COVERAGE_ASSESSMENT</td><td>DOUBLE</td><td><p>Cloudy pixel percentage for the whole archive that\ncontains this granule. Taken from the original metadata</p></td></tr><tr><td>DATASTRIP_ID</td><td>STRING</td><td><p>Unique identifier of the datastrip Product Data Item (PDI)</p></td></tr><tr><td>DATATAKE_IDENTIFIER</td><td>STRING</td><td><p>Uniquely identifies a given Datatake. The ID contains\nthe Sentinel-2 satellite, start date a ...
#   'source_tags': ['eu', 'esa', 'copernicus', 'sentinel'],
#   'visualization_0_max': '3000.0',
#   'provider_url': 'https://earth.esa.int/web/sentinel/user-guides/sentinel-2-msi/product-types/level-1c',
#   'title': 'Sentinel-2 MSI: MultiSpectral Instrument, Level-1C',
#   'sample': 'https://mw1.google.com/ges/dd/images/sentinel2_sample.png',
#   'tags': ['copernicus', 'esa', 'eu', 'msi', 'radiance', 'sentinel'],
#   'system:visualization_0_max': '3000.0',
#   'product_tags': ['msi', 'radiance'],
#   'provider': 'European Union/ESA/Copernicus',
#   'visualization_0_min': '0.0',
#   'system:visualization_0_name': 'RGB',
#   'visualization_0_name': 'RGB',
#   'visualization_0_bands': 'B4,B3,B2'},
#  'features': [{'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B9',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_OPAQUE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_CIRRUS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_SNOW_ICE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]}],
#    'version': 1742414438806166,
#    'id': 'COPERNICUS/S2_HARMONIZED/20250118T094229_20250118T094230_T34UDA',
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2B_20250118T094229_041103_N05.11',
#     'SPACECRAFT_NAME': 'Sentinel-2B',
#     'RADIO_ADD_OFFSET_B8A': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 104.680597186882,
#     'RADIO_ADD_OFFSET_B10': -1000,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 164.662184134613,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[19.616742867123165, 49.55657819576685],
#       [19.616760172118997, 49.55657773544778],
#       [21.13469416159067, 49.56476652522964],
#       [21.134758212777893, 49.564802999014226],
#       [21.134828776689634, 49.564834002501435],
#       [21.134833148688237, 49.564848777221044],
#       [21.137629013618138, 50.55221079623426],
#       [21.137571642751126, 50.55225234524685],
#       [21.137522784446606, 50.5522980655666],
#       [21.13749953144082, 50.55230090593945],
#       [19.588083412198397, 50.5438222755052],
#       [19.588019253386122, 50.54378495160492],
#       [19.587948321316702, 50.543752997876574],
#       [19.587944387523383, 50.54373816620149],
#       [19.60248044605535, 50.050220923744725],
#       [19.6166189410529, 49.556666070790655],
#       [19.616676455642107, 49.55662525833787],
#       [19.616725743105928, 49.55658007808814],
#       [19.616742867123165, 49.55657819576685]]},
#     'SOLAR_IRRADIANCE_B12': 87.75,
#     'SOLAR_IRRADIANCE_B10': 365.41,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 247.08,
#     'GENERATION_TIME': 1737196086000,
#     'RADIO_ADD_OFFSET_B12': -1000,
#     'RADIO_ADD_OFFSET_B11': -1000,
#     'SOLAR_IRRADIANCE_B8A': 953.93,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 0,
#     'system:time_end': 1737193602822,
#     'SNOW_PIXEL_PERCENTAGE': 61.7526053330945,
#     'system:time_start': 1737193602822,
#     'RADIO_ADD_OFFSET_B1': -1000,
#     'RADIO_ADD_OFFSET_B2': -1000,
#     'DATASTRIP_ID': 'S2B_OPER_MSI_L1C_DS_2BPS_20250118T102806_S20250118T094230_N05.11',
#     'RADIO_ADD_OFFSET_B3': -1000,
#     'RADIO_ADD_OFFSET_B4': -1000,
#     'RADIO_ADD_OFFSET_B5': -1000,
#     'PROCESSING_BASELINE': '05.11',
#     'SENSING_ORBIT_NUMBER': 36,
#     'RADIO_ADD_OFFSET_B6': -1000,
#     'RADIO_ADD_OFFSET_B7': -1000,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L1C_T34UDA_A041103_20250118T094230',
#     'REFLECTANCE_CONVERSION_CORRECTION': 1.03365709979694,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 107.951765916245,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 104.299640607341,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 105.28704828378,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 104.981162370247,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 106.140539446103,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 4.98690814169696,
#     'RADIO_ADD_OFFSET_B8': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 105.715592896646,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'RADIO_ADD_OFFSET_B9': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 108.890764069818,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 107.196406066212,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 4.7524494491929,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 104.512983908645,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 4.70271487007752,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 4.62272467079786,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 4.55508601391122,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 5.05586511757587,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 4.58611970877099,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 4.85915848219371,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 4.80174356054788,
#     'MEAN_SOLAR_ZENITH_ANGLE': 71.8425925391026,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 4.92215505845171,
#     'MGRS_TILE': '34UDA',
#     'CLOUDY_PIXEL_PERCENTAGE': 0,
#     'PRODUCT_ID': 'S2B_MSIL1C_20250118T094229_N0511_R036_T34UDA_20250118T102806',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 4.67792265305947,
#     'SOLAR_IRRADIANCE_B9': 817.58,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0.0218,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 4.79779669276318,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 4.93873111088717,
#     'SOLAR_IRRADIANCE_B6': 1291.13,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 106.572245934809,
#     'SOLAR_IRRADIANCE_B5': 1425.78,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 105.50381750593,
#     'SOLAR_IRRADIANCE_B8': 1041.28,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 104.811587528386,
#     'SOLAR_IRRADIANCE_B7': 1175.57,
#     'SOLAR_IRRADIANCE_B2': 1959.75,
#     'SOLAR_IRRADIANCE_B1': 1874.3,
#     'SOLAR_IRRADIANCE_B4': 1512.79,
#     'GEOMETRIC_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B3': 1824.93,
#     'system:asset_size': 1477400099,
#     'system:index': '20250118T094229_20250118T094230_T34UDA'}},
#   {'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B9',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_OPAQUE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_CIRRUS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_SNOW_ICE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]}],
#    'version': 1742414438806166,
#    'id': 'COPERNICUS/S2_HARMONIZED/20250126T095331_20250126T095327_T34UDA',
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2C_20250126T095331_002051_N05.11',
#     'SPACECRAFT_NAME': 'Sentinel-2C',
#     'RADIO_ADD_OFFSET_B8A': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 288.87469357166,
#     'RADIO_ADD_OFFSET_B10': -1000,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 166.379153815915,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[19.6166189410529, 49.556666070790655],
#       [19.61672874085912, 49.556577369838124],
#       [20.533440531297565, 49.56390445273795],
#       [20.53394163339945, 49.56401532178294],
#       [20.539664658871356, 49.57541487117583],
#       [20.647742640523344, 49.798770157231324],
#       [20.797644564036382, 50.10555916682543],
#       [20.861456463949843, 50.23543335581675],
#       [20.893282529934496, 50.29995137370308],
#       [20.991393149279066, 50.498575132524074],
#       [20.99393043030274, 50.503701537592185],
#       [21.016791562312648, 50.55010676655558],
#       [21.017640615794495, 50.55199840904289],
#       [21.01764504316874, 50.552020954351704],
#       [21.017645181543283, 50.552290748095984],
#       [21.01753571087975, 50.552380781146326],
#       [19.587941863976454, 50.54382055124429],
#       [19.60248044605535, 50.050220923744725],
#       [19.6166189410529, 49.556666070790655]]},
#     'SOLAR_IRRADIANCE_B12': 86.94,
#     'SOLAR_IRRADIANCE_B10': 367.88,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 246.31,
#     'GENERATION_TIME': 1737892233000,
#     'RADIO_ADD_OFFSET_B12': -1000,
#     'RADIO_ADD_OFFSET_B11': -1000,
#     'SOLAR_IRRADIANCE_B8A': 957.92,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 14.673578469219,
#     'system:time_end': 1737885428065,
#     'SNOW_PIXEL_PERCENTAGE': 10.1720675879796,
#     'system:time_start': 1737885428065,
#     'RADIO_ADD_OFFSET_B1': -1000,
#     'RADIO_ADD_OFFSET_B2': -1000,
#     'DATASTRIP_ID': 'S2C_OPER_MSI_L1C_DS_2CPS_20250126T115033_S20250126T095327_N05.11',
#     'RADIO_ADD_OFFSET_B3': -1000,
#     'RADIO_ADD_OFFSET_B4': -1000,
#     'RADIO_ADD_OFFSET_B5': -1000,
#     'PROCESSING_BASELINE': '05.11',
#     'SENSING_ORBIT_NUMBER': 79,
#     'RADIO_ADD_OFFSET_B6': -1000,
#     'RADIO_ADD_OFFSET_B7': -1000,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L1C_T34UDA_A002051_20250126T095327',
#     'REFLECTANCE_CONVERSION_CORRECTION': 1.03239955160837,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 287.971711593049,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 289.095514954787,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 288.606759515858,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 288.734224709585,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 288.344930695478,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 8.62613058580419,
#     'RADIO_ADD_OFFSET_B8': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 288.467624870941,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'RADIO_ADD_OFFSET_B9': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 287.854233487384,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 288.096088533953,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 8.52145496705331,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 288.995508035025,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 8.50063051797785,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 8.46078301460063,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 8.43351075774611,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 8.65784578843673,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 8.44194548803243,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 8.57043343621226,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 8.54477674351603,
#     'MEAN_SOLAR_ZENITH_ANGLE': 69.6827334449255,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 8.59855592515225,
#     'MGRS_TILE': '34UDA',
#     'CLOUDY_PIXEL_PERCENTAGE': 14.6735784692188,
#     'PRODUCT_ID': 'S2C_MSIL1C_20250126T095331_N0511_R079_T34UDA_20250126T115033',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 8.48430190107574,
#     'SOLAR_IRRADIANCE_B9': 807.65,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0.0152,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 8.53952803277451,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 8.6057003894631,
#     'SOLAR_IRRADIANCE_B6': 1287.62,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 288.311123715263,
#     'SOLAR_IRRADIANCE_B5': 1410.66,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 288.63661087634,
#     'SOLAR_IRRADIANCE_B8': 1037.17,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 288.982349257246,
#     'SOLAR_IRRADIANCE_B7': 1154.97,
#     'SOLAR_IRRADIANCE_B2': 1972.03,
#     'SOLAR_IRRADIANCE_B1': 1914.61,
#     'SOLAR_IRRADIANCE_B4': 1506.74,
#     'GEOMETRIC_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B3': 1822.48,
#     'system:asset_size': 1042532904,
#     'system:index': '20250126T095331_20250126T095327_T34UDA'}},
#   {'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B9',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_OPAQUE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_CIRRUS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_SNOW_ICE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]}],
#    'version': 1742414438806166,
#    'id': 'COPERNICUS/S2_HARMONIZED/20250123T094341_20250123T094503_T34UDA',
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2C_20250123T094341_002008_N05.11',
#     'SPACECRAFT_NAME': 'Sentinel-2C',
#     'RADIO_ADD_OFFSET_B8A': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 104.050366695018,
#     'RADIO_ADD_OFFSET_B10': -1000,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 164.222846949198,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[19.616742867123165, 49.55657819576685],
#       [19.616760172118997, 49.55657773544778],
#       [21.13469416159067, 49.56476652522964],
#       [21.134758212777893, 49.564802999014226],
#       [21.134828776689634, 49.564834002501435],
#       [21.134833148688237, 49.564848777221044],
#       [21.137629013618138, 50.55221079623426],
#       [21.137571642751126, 50.55225234524685],
#       [21.137522784446606, 50.5522980655666],
#       [21.13749953144082, 50.55230090593945],
#       [19.588083412198397, 50.5438222755052],
#       [19.588019253386122, 50.54378495160492],
#       [19.587948321316702, 50.543752997876574],
#       [19.587944387523383, 50.54373816620149],
#       [19.60248044605535, 50.050220923744725],
#       [19.6166189410529, 49.556666070790655],
#       [19.616676455642107, 49.55662525833787],
#       [19.616725743105928, 49.55658007808814],
#       [19.616742867123165, 49.55657819576685]]},
#     'SOLAR_IRRADIANCE_B12': 86.94,
#     'SOLAR_IRRADIANCE_B10': 367.88,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 246.31,
#     'GENERATION_TIME': 1737632378000,
#     'RADIO_ADD_OFFSET_B12': -1000,
#     'RADIO_ADD_OFFSET_B11': -1000,
#     'SOLAR_IRRADIANCE_B8A': 957.92,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 23.305503299591,
#     'system:time_end': 1737625632150,
#     'SNOW_PIXEL_PERCENTAGE': 35.8437098748843,
#     'system:time_start': 1737625632150,
#     'RADIO_ADD_OFFSET_B1': -1000,
#     'RADIO_ADD_OFFSET_B2': -1000,
#     'DATASTRIP_ID': 'S2C_OPER_MSI_L1C_DS_2CPS_20250123T113938_S20250123T094503_N05.11',
#     'RADIO_ADD_OFFSET_B3': -1000,
#     'RADIO_ADD_OFFSET_B4': -1000,
#     'RADIO_ADD_OFFSET_B5': -1000,
#     'PROCESSING_BASELINE': '05.11',
#     'SENSING_ORBIT_NUMBER': 36,
#     'RADIO_ADD_OFFSET_B6': -1000,
#     'RADIO_ADD_OFFSET_B7': -1000,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L1C_T34UDA_A002008_20250123T094503',
#     'REFLECTANCE_CONVERSION_CORRECTION': 1.03294677366229,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 106.815962776451,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 103.921072491599,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 104.504217532788,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 104.282106220225,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 105.203484684237,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 4.88750501320511,
#     'RADIO_ADD_OFFSET_B8': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 104.83274847284,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'RADIO_ADD_OFFSET_B9': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 107.651247058691,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 106.137418216465,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 4.6428595520462,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 104.106840401756,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 4.59118241562535,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 4.50756858339069,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 4.43505000967883,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 4.95223668319819,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 4.46867143521437,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 4.76088053345097,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 4.69839383753333,
#     'MEAN_SOLAR_ZENITH_ANGLE': 70.7897805736449,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 4.82363328020882,
#     'MGRS_TILE': '34UDA',
#     'CLOUDY_PIXEL_PERCENTAGE': 23.3055032995909,
#     'PRODUCT_ID': 'S2C_MSIL1C_20250123T094341_N0511_R036_T34UDA_20250123T113938',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 4.56573476874575,
#     'SOLAR_IRRADIANCE_B9': 807.65,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0.0216,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 4.69359023787799,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 4.83300385179594,
#     'SOLAR_IRRADIANCE_B6': 1287.62,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 105.316794911785,
#     'SOLAR_IRRADIANCE_B5': 1410.66,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 104.406274047894,
#     'SOLAR_IRRADIANCE_B8': 1037.17,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 103.862738370957,
#     'SOLAR_IRRADIANCE_B7': 1154.97,
#     'SOLAR_IRRADIANCE_B2': 1972.03,
#     'SOLAR_IRRADIANCE_B1': 1914.61,
#     'SOLAR_IRRADIANCE_B4': 1506.74,
#     'GEOMETRIC_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B3': 1822.48,
#     'system:asset_size': 1442880303,
#     'system:index': '20250123T094341_20250123T094503_T34UDA'}},
#   {'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B9',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_OPAQUE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_CIRRUS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_SNOW_ICE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]}],
#    'version': 1742414438806166,
#    'id': 'COPERNICUS/S2_HARMONIZED/20250131T095139_20250131T095138_T34UDA',
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2B_20250131T095139_041289_N05.11',
#     'SPACECRAFT_NAME': 'Sentinel-2B',
#     'RADIO_ADD_OFFSET_B8A': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 287.859390001314,
#     'RADIO_ADD_OFFSET_B10': -1000,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 165.815186726142,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[21.031994415290725, 50.55232102866699],
#       [21.031956552183367, 50.55237336489212],
#       [21.031901727760527, 50.55237775898368],
#       [19.588083412198397, 50.5438222755052],
#       [19.58794393459061, 50.54375105422572],
#       [19.60248044605535, 50.050220923744725],
#       [19.6166189410529, 49.556666070790655],
#       [19.61672874085912, 49.556577369838124],
#       [20.548352624504464, 49.56396364094763],
#       [20.54840913651676, 49.56397013140908],
#       [20.549255969580297, 49.56434213738187],
#       [20.54929220282913, 49.56436316552785],
#       [20.550127191499, 49.56546582247647],
#       [20.82856476621025, 50.14041530009616],
#       [21.00239055768344, 50.49236995883306],
#       [21.01932191407384, 50.52636295439445],
#       [21.029492866040425, 50.54686605650722],
#       [21.032043575736388, 50.552275153667544],
#       [21.031994415290725, 50.55232102866699]]},
#     'SOLAR_IRRADIANCE_B12': 87.75,
#     'SOLAR_IRRADIANCE_B10': 365.41,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 247.08,
#     'GENERATION_TIME': 1738327306000,
#     'RADIO_ADD_OFFSET_B12': -1000,
#     'RADIO_ADD_OFFSET_B11': -1000,
#     'SOLAR_IRRADIANCE_B8A': 953.93,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 39.373116605935,
#     'system:time_end': 1738317402513,
#     'SNOW_PIXEL_PERCENTAGE': 0.1810536898742,
#     'system:time_start': 1738317402513,
#     'RADIO_ADD_OFFSET_B1': -1000,
#     'RADIO_ADD_OFFSET_B2': -1000,
#     'DATASTRIP_ID': 'S2B_OPER_MSI_L1C_DS_2BPS_20250131T124146_S20250131T095138_N05.11',
#     'RADIO_ADD_OFFSET_B3': -1000,
#     'RADIO_ADD_OFFSET_B4': -1000,
#     'RADIO_ADD_OFFSET_B5': -1000,
#     'PROCESSING_BASELINE': '05.11',
#     'SENSING_ORBIT_NUMBER': 79,
#     'RADIO_ADD_OFFSET_B6': -1000,
#     'RADIO_ADD_OFFSET_B7': -1000,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L1C_T34UDA_A041289_20250131T095138',
#     'REFLECTANCE_CONVERSION_CORRECTION': 1.03129551480437,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 286.95123362713,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 288.075676684497,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 287.58803680516,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 287.717910254002,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 287.324580521968,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 8.63264177113711,
#     'RADIO_ADD_OFFSET_B8': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 287.448085585191,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'RADIO_ADD_OFFSET_B9': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 286.830458663548,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 287.076153891515,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 8.5290254415637,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 287.931290038997,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 8.50852954006599,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 8.46925483413311,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 8.44473320434769,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 8.66597238512313,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 8.45575317718022,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 8.57739418010813,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 8.55197973048393,
#     'MEAN_SOLAR_ZENITH_ANGLE': 68.4078922626006,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 8.60510417980233,
#     'MGRS_TILE': '34UDA',
#     'CLOUDY_PIXEL_PERCENTAGE': 39.3731166059346,
#     'PRODUCT_ID': 'S2B_MSIL1C_20250131T095139_N0511_R079_T34UDA_20250131T124146',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 8.490623234006,
#     'SOLAR_IRRADIANCE_B9': 817.58,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0.026,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 8.54827027473802,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 8.61159412636971,
#     'SOLAR_IRRADIANCE_B6': 1291.13,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 287.144374679576,
#     'SOLAR_IRRADIANCE_B5': 1425.78,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 287.489687054804,
#     'SOLAR_IRRADIANCE_B8': 1041.28,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 287.813459265167,
#     'SOLAR_IRRADIANCE_B7': 1175.57,
#     'SOLAR_IRRADIANCE_B2': 1959.75,
#     'SOLAR_IRRADIANCE_B1': 1874.3,
#     'SOLAR_IRRADIANCE_B4': 1512.79,
#     'GEOMETRIC_QUALITY': 'FAILED',
#     'SOLAR_IRRADIANCE_B3': 1824.93,
#     'system:asset_size': 1049938692,
#     'system:index': '20250131T095139_20250131T095138_T34UDA'}},
#   {'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B9',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_OPAQUE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_CIRRUS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_SNOW_ICE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]}],
#    'version': 1742414438806166,
#    'id': 'COPERNICUS/S2_HARMONIZED/20250103T094411_20250103T094408_T34UDA',
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2A_20250103T094411_049797_N05.11',
#     'SPACECRAFT_NAME': 'Sentinel-2A',
#     'RADIO_ADD_OFFSET_B8A': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 103.717462889855,
#     'RADIO_ADD_OFFSET_B10': -1000,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 166.488516010089,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[19.616742867123165, 49.55657819576685],
#       [19.616760172118997, 49.55657773544778],
#       [21.13469416159067, 49.56476652522964],
#       [21.134758212777893, 49.564802999014226],
#       [21.134828776689634, 49.564834002501435],
#       [21.134833148688237, 49.564848777221044],
#       [21.137629013618138, 50.55221079623426],
#       [21.137571642751126, 50.55225234524685],
#       [21.137522784446606, 50.5522980655666],
#       [21.13749953144082, 50.55230090593945],
# ...
#     {'id': 'B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_OPAQUE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_CIRRUS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_SNOW_ICE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]}],
#    'version': 1742414438806166,
#    'id': 'COPERNICUS/S2_HARMONIZED/20250116T095341_20250116T095355_T34UDA',
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2A_20250116T095341_049983_N05.11',
#     'SPACECRAFT_NAME': 'Sentinel-2A',
#     'RADIO_ADD_OFFSET_B8A': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 288.613985774916,
#     'RADIO_ADD_OFFSET_B10': -1000,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 167.303991445669,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[21.008311525672234, 50.49111068839513],
#       [21.01000391988135, 50.494528035071994],
#       [21.038531752205685, 50.55208278489536],
#       [21.038536366282045, 50.552105874584115],
#       [21.03853650309959, 50.5522857176504],
#       [21.0384270621197, 50.55237577390821],
#       [19.588083412198397, 50.5438222755052],
#       [19.58794393459061, 50.54375105422572],
#       [19.60248044605535, 50.050220923744725],
#       [19.6166189410529, 49.556666070790655],
#       [19.61672874085912, 49.556577369838124],
#       [20.554494648763637, 49.56398746396292],
#       [20.55483356708111, 49.56421049920403],
#       [20.640390114564457, 49.7408233535083],
#       [20.67324584460353, 49.80837892203578],
#       [20.77125122554649, 50.00972438427228],
#       [20.808213356515452, 50.08534087988857],
#       [20.838617047713203, 50.1474449567294],
#       [21.008311525672234, 50.49111068839513]]},
#     'SOLAR_IRRADIANCE_B12': 85.25,
#     'SOLAR_IRRADIANCE_B10': 367.15,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 245.59,
#     'GENERATION_TIME': 1737024271000,
#     'RADIO_ADD_OFFSET_B12': -1000,
#     'RADIO_ADD_OFFSET_B11': -1000,
#     'SOLAR_IRRADIANCE_B8A': 955.32,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 99.720047763342,
#     'system:time_end': 1737021398210,
#     'SNOW_PIXEL_PERCENTAGE': 0.174153204072955,
#     'system:time_start': 1737021398210,
#     'RADIO_ADD_OFFSET_B1': -1000,
#     'RADIO_ADD_OFFSET_B2': -1000,
#     'DATASTRIP_ID': 'S2A_OPER_MSI_L1C_DS_2APS_20250116T104431_S20250116T095355_N05.11',
#     'RADIO_ADD_OFFSET_B3': -1000,
#     'RADIO_ADD_OFFSET_B4': -1000,
#     'RADIO_ADD_OFFSET_B5': -1000,
#     'PROCESSING_BASELINE': '05.11',
#     'SENSING_ORBIT_NUMBER': 79,
#     'RADIO_ADD_OFFSET_B6': -1000,
#     'RADIO_ADD_OFFSET_B7': -1000,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L1C_T34UDA_A049983_20250116T095355',
#     'REFLECTANCE_CONVERSION_CORRECTION': 1.03386943026112,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 287.744383472481,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 288.832008747605,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 288.329444222693,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 288.509240874041,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 288.055247955734,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 8.62661632678582,
#     'RADIO_ADD_OFFSET_B8': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 288.148275583437,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'RADIO_ADD_OFFSET_B9': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 287.63104019944,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 287.842851321856,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 8.50326029284157,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 288.669674601558,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 8.48537050984208,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 8.45343049753265,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 8.43000807418301,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 8.65882454007571,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 8.44133330281379,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 8.56026578765946,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 8.52999611644632,
#     'MEAN_SOLAR_ZENITH_ANGLE': 71.8238682966385,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 8.59458771026766,
#     'MGRS_TILE': '34UDA',
#     'CLOUDY_PIXEL_PERCENTAGE': 99.7200477633423,
#     'PRODUCT_ID': 'S2A_MSIL1C_20250116T095341_N0511_R079_T34UDA_20250116T104431',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 8.48517481082216,
#     'SOLAR_IRRADIANCE_B9': 812.92,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0.0285,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 8.54258664748096,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 8.60988611622591,
#     'SOLAR_IRRADIANCE_B6': 1287.61,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 287.951994381814,
#     'SOLAR_IRRADIANCE_B5': 1424.64,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 288.258391562614,
#     'SOLAR_IRRADIANCE_B8': 1041.63,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 288.545187268164,
#     'SOLAR_IRRADIANCE_B7': 1162.08,
#     'SOLAR_IRRADIANCE_B2': 1959.66,
#     'SOLAR_IRRADIANCE_B1': 1884.69,
#     'SOLAR_IRRADIANCE_B4': 1512.06,
#     'GEOMETRIC_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B3': 1823.24,
#     'system:asset_size': 1103448753,
#     'system:index': '20250116T095341_20250116T095355_T34UDA'}},
#   {'type': 'Image',
#    'bands': [{'id': 'B1',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B2',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B3',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B4',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B5',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B6',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B7',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B8',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [10980, 10980],
#      'crs': 'EPSG:32634',
#      'crs_transform': [10, 0, 399960, 0, -10, 5600040]},
#     {'id': 'B8A',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B9',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'B11',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'B12',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [5490, 5490],
#      'crs': 'EPSG:32634',
#      'crs_transform': [20, 0, 399960, 0, -20, 5600040]},
#     {'id': 'QA10',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA20',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 4294967295},
#      'crs': 'EPSG:4326',
#      'crs_transform': [1, 0, 0, 0, 1, 0]},
#     {'id': 'QA60',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 65535},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_OPAQUE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_CIRRUS',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]},
#     {'id': 'MSK_CLASSI_SNOW_ICE',
#      'data_type': {'type': 'PixelType',
#       'precision': 'int',
#       'min': 0,
#       'max': 255},
#      'dimensions': [1830, 1830],
#      'crs': 'EPSG:32634',
#      'crs_transform': [60, 0, 399960, 0, -60, 5600040]}],
#    'version': 1742414438806166,
#    'id': 'COPERNICUS/S2_HARMONIZED/20250101T095319_20250101T095321_T34UDA',
#    'properties': {'DATATAKE_IDENTIFIER': 'GS2B_20250101T095319_040860_N05.11',
#     'SPACECRAFT_NAME': 'Sentinel-2B',
#     'RADIO_ADD_OFFSET_B8A': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 287.877045002249,
#     'RADIO_ADD_OFFSET_B10': -1000,
#     'MEAN_SOLAR_AZIMUTH_ANGLE': 169.105678356316,
#     'system:footprint': {'type': 'LinearRing',
#      'coordinates': [[19.6166189410529, 49.556666070790655],
#       [19.61672874085912, 49.556577369838124],
#       [20.549224378850713, 49.56396701522608],
#       [20.550116183740837, 49.56435875130607],
#       [20.550956440695106, 49.56546845906621],
#       [20.55177465893018, 49.56709722957657],
#       [20.64251286113499, 49.75414167960438],
#       [20.83192331804406, 50.140420004638436],
#       [20.897972039097958, 50.27378406335662],
#       [20.927351563219286, 50.33316387599887],
#       [20.998161833547535, 50.47618207656298],
#       [21.02440233712585, 50.529060165405],
#       [21.028640358664294, 50.53769301970068],
#       [21.035426119950756, 50.55172421472206],
#       [21.035430729966922, 50.55174713960881],
#       [21.03543104152464, 50.55228676119975],
#       [21.035321650550763, 50.55237672111858],
#       [19.587941863976454, 50.54382055124429],
#       [19.60248044605535, 50.050220923744725],
#       [19.6166189410529, 49.556666070790655]]},
#     'SOLAR_IRRADIANCE_B12': 87.75,
#     'SOLAR_IRRADIANCE_B10': 365.41,
#     'SENSOR_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B11': 247.08,
#     'GENERATION_TIME': 1735731978000,
#     'RADIO_ADD_OFFSET_B12': -1000,
#     'RADIO_ADD_OFFSET_B11': -1000,
#     'SOLAR_IRRADIANCE_B8A': 953.93,
#     'FORMAT_CORRECTNESS': 'PASSED',
#     'CLOUD_COVERAGE_ASSESSMENT': 99.998917945069,
#     'system:time_end': 1735725400427,
#     'SNOW_PIXEL_PERCENTAGE': 0,
#     'system:time_start': 1735725400427,
#     'RADIO_ADD_OFFSET_B1': -1000,
#     'RADIO_ADD_OFFSET_B2': -1000,
#     'DATASTRIP_ID': 'S2B_OPER_MSI_L1C_DS_2BPS_20250101T114618_S20250101T095321_N05.11',
#     'RADIO_ADD_OFFSET_B3': -1000,
#     'RADIO_ADD_OFFSET_B4': -1000,
#     'RADIO_ADD_OFFSET_B5': -1000,
#     'PROCESSING_BASELINE': '05.11',
#     'SENSING_ORBIT_NUMBER': 79,
#     'RADIO_ADD_OFFSET_B6': -1000,
#     'RADIO_ADD_OFFSET_B7': -1000,
#     'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#     'GENERAL_QUALITY': 'PASSED',
#     'GRANULE_ID': 'L1C_T34UDA_A040860_20250101T095321',
#     'REFLECTANCE_CONVERSION_CORRECTION': 1.03414990946787,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 286.950410430869,
#     'DATATAKE_TYPE': 'INS-NOBS',
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 288.096279640293,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 287.565622563313,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 287.693566480523,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 287.310457332405,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 8.63020492900042,
#     'RADIO_ADD_OFFSET_B8': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 287.450754160245,
#     'RADIOMETRIC_QUALITY': 'PASSED',
#     'RADIO_ADD_OFFSET_B9': -1000,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 286.82917910539,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 287.07577105671,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 8.51429828824252,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 287.950402044488,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 8.49692923210247,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 8.46055102564246,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 8.43602018448065,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 8.66351619129894,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 8.44704486205341,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 8.5690657452023,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 8.5436387953404,
#     'MEAN_SOLAR_ZENITH_ANGLE': 73.7142306355531,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 8.60270731190949,
#     'MGRS_TILE': '34UDA',
#     'CLOUDY_PIXEL_PERCENTAGE': 99.9989179450695,
#     'PRODUCT_ID': 'S2B_MSIL1C_20250101T095319_N0511_R079_T34UDA_20250101T114618',
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 8.48183757651302,
#     'SOLAR_IRRADIANCE_B9': 817.58,
#     'DEGRADED_MSI_DATA_PERCENTAGE': 0.0259,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 8.53993154859196,
#     'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 8.60156651547434,
#     'SOLAR_IRRADIANCE_B6': 1291.13,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 287.173955711422,
#     'SOLAR_IRRADIANCE_B5': 1425.78,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 287.467499572077,
#     'SOLAR_IRRADIANCE_B8': 1041.28,
#     'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 287.753552829581,
#     'SOLAR_IRRADIANCE_B7': 1175.57,
#     'SOLAR_IRRADIANCE_B2': 1959.75,
#     'SOLAR_IRRADIANCE_B1': 1874.3,
#     'SOLAR_IRRADIANCE_B4': 1512.79,
#     'GEOMETRIC_QUALITY': 'PASSED',
#     'SOLAR_IRRADIANCE_B3': 1824.93,
#     'system:asset_size': 956209889,
#     'system:index': '20250101T095319_20250101T095321_T34UDA'}}]}

# %% [markdown]
# ## Task 5: Visualize Image
# Create a map and visualize the Sentinel-2 image using different visualization parameters (e.g., true color, false color).

# %%
# Visualization
# TODO: Create visualization layers using true color and false color compositions
# Example parameters provided below:
true_color_params = {'bands': ['B4', 'B3', 'B2'], 'min': 0, 'max': 3000}
false_color_params = {'bands': ['B8', 'B4', 'B3'], 'min': 0, 'max': 5000}



# TODO: Add these layers to an interactive map
map = geemap.Map(center=[point[1], point[0]], zoom=10)
map.addLayer(best_image, true_color_params, 'true_color')
map.addLayer(best_image, false_color_params, 'false_color')
map.addLayerControl()


map.save("map.html")
webbrowser.open("map.html")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# True

# %% [markdown]
# ## Submission
# Save your completed notebook and submit it to your course repository.
